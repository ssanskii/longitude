# %%
from numerical import RockTransit

# %%
r = RockTransit(npoints=500)
r.simulate(plot=True, bat=True)
# Out:
# 19.47122063449069

# %%
from a import plot_compare

# %%
import numpy as np
plot_compare(R = 2, R_s= 1, d = 1.5, theta = np.pi/2, h =0.5, multiplier=10000)
# Out:
# Numerical value is 0.61407994
# Analytical value is 5.869834432471555

# %%
import int_final as int
import numpy as np

int.plot_compare(1.0, 0.26530894318567616, 0.8992157598889061, -4.712388980384691, -0.26530894318567616, plot=True, multiplier= 5000)
# Out:
# Numerical value is 0.15727
# Analytical value is 0.15514419502900545
# With multiplier = 5000, difference is one part per 72

# %%
from lightcurve import LightCurve
import numpy as np
def I(x):
    return 1

angle = 0 * (np.pi/180)
test = LightCurve(0.447, 0.1457, 0.1457, 0.1457, I, 11.37, wind=angle)
test.simulate(0.25, 1000, n_bands=50, n_slices=50)
print(1 - test.small_curve / np.pi)
test.plots()
# Out:
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# outside
# ...

# %%
from cross_section import get_z_range

z = get_z_range(0.2, 0.3, 0.1, theta = 0)
print(z)
# Out:
# None

# %%
arr1 = [12,13,14,15]
arr2 = [51,52,53,54]

for  i, j in enumerate(zip(arr1, arr2)):
    # print(n)
    print(i)
    print(j)
# Out:
# 0
# (12, 51)
# 1
# (13, 52)
# 2
# (14, 53)
# 3
# (15, 54)
