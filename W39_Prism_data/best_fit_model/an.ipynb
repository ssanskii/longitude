# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
filename = 'best_fit_model.h5'

with h5py.File(filename, 'r') as f:
    print("Keys: %s" % f.keys())
    td_key = list(f.keys())[0]
    wv_key = list(f.keys())[1]
    td_dset = f[td_key][()]
    wv_dset = f[wv_key][()]
    print(wv_dset)
    print(td_dset)

plt.plot(wv_dset, td_dset, 'x', markersize = 0.05)
plt.savefig('test.pdf')
# Out:
# Keys: <KeysViewHDF5 ['transit_depth', 'wavelength']>
# [5.59996423 5.59987089 5.59977756 ... 0.3000444  0.3000294  0.3000144 ]
# [0.0212524  0.02140603 0.02107508 ... 0.02107896 0.02107899 0.02107903]
