# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
import batman
from scipy.optimize import curve_fit
filename = 'Tiberius_normalized_specphot.h5'
hours = 8.23
with h5py.File(filename, 'r') as f:
    print("Keys: %s" % f.keys())
    flux_key = list(f.keys())[0]
    print(flux_key)
    flux = f[flux_key][()]
    print(flux.shape)
    print(flux)
    
    # for i in range(flux.shape[0]):
    #     y = flux[i]
    #     x = np.linspace(-hours/2, hours/2, len(y))
    #     plt.plot(x,y,'x', markersize = 0.1)
    #     plt.ylim([0.95,1.1])
    #     plt.show()
# Out:
# Keys: <KeysViewHDF5 ['specphot']>
# specphot
# (440, 19486)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 14
#      12 flux = f[flux_key][()]
#      13 print(flux.shape)
# ---> 14 print(flux.type)
#      16 # for i in range(flux.shape[0]):
#      17 #     y = flux[i]
#      18 #     x = np.linspace(-hours/2, hours/2, len(y))
#      19 #     plt.plot(x,y,'x', markersize = 0.1)
#      20 #     plt.ylim([0.95,1.1])
#      21 #     plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'
